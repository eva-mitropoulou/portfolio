# %% [markdown]
# # Antibody Sequence ML Workflow
#
# Recruiter-readable walkthrough for the public-data antibody sequence ML benchmark and existing-record prioritization workflow. This notebook uses cached public-safe summary metrics only. It does not print biological sequences or raw data rows.

# %% [markdown]
# ## 1. Goal
#
# Evaluate a finished retrospective public-data antibody sequence ML workflow with leakage-aware validation, whole-pair k-mer scoring, antibody representation benchmarks, source-holdout/source-robust controls, calibration limits, and existing-record prioritization. The output is benchmark evidence and record triage, not therapeutic antibody design.

# %% [markdown]
# ## 2. Input Data
#
# Evidence comes from committed reports and metric summaries derived from CoV-AbDab-prepared records, CDR annotation outputs, OAS background-retrieval summaries, and benchmark reports. OAS records are treated as unknown-target background, not true negatives.

# %%
import json
from pathlib import Path

summary_path = Path("../antibody-sequence-ml/reports/metrics/summary.json")
summary = json.loads(summary_path.read_text())
summary["data_scope"]

# %% [markdown]
# ## 3. Cleaning / Preprocessing
#
# The full workflow includes sequence cleaning, strict labeled table construction, broader prepared-record construction, paired-record annotation, and quality-gate audits. This notebook keeps only aggregate counts and validated metric summaries.

# %% [markdown]
# ## 4. Features / Models
#
# Public evidence includes character k-mer TF-IDF baselines, CDR/region-local k-mer comparisons, antibody embedding baselines, frozen pretrained representation benchmarks, and IgBert/BERT-family benchmark artifacts where present. The final selected broad scorer is `whole_pair_kmer`: compact heavy/light whole-pair k-mer TF-IDF with balanced logistic regression.

# %%
summary["validation"]

# %% [markdown]
# ## 5. Validation
#
# Grouped validation is prioritized where group features are meaningful. Source-holdout validation and source-robust model selection provide skeptical controls for source/study effects. OAS retrieval is kept separate from the neutralization benchmark because OAS records are unknown-target background, not true negatives.

# %%
{
    "final_selected_model": summary["final_selected_model"],
    "validation": summary["validation"],
    "calibration_and_thresholds": summary["calibration_and_thresholds"],
}

# %% [markdown]
# ## 6. Results
#
# The mature public result is intentionally bounded: whole-pair k-mer TF-IDF logistic regression remained the most defensible broad scorer. It performed strongly under V-gene grouped validation but only modestly under source-holdout validation, showing public-label source/study effects. The workflow is useful for retrospective prioritization and high-confidence review, not as a calibrated prospective neutralisation predictor.

# %%
{
    "oas_background_retrieval": summary["oas_background_retrieval"],
    "prioritization": summary["prioritization"],
    "packaging": summary["packaging"],
}

# %% [markdown]
# ## 7. Limitations
#
# Retrospective public labels, heterogeneous assays/sources, source/study effects, no prospective validation, no therapeutic design, and OAS as unknown-target background rather than true negatives. Model scores are prioritization signals, not calibrated prospective neutralisation probabilities.
